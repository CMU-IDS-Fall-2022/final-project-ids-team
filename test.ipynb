# %%
import pandas as pd

df = pd.read_csv('Spotify-2000.csv')

# %%
df['Top Genre'].value_counts()
# Out:
# album rock           413
# adult standards      123
# dutch pop             88
# alternative rock      86
# dance pop             83
#                     ...
# streektaal             1
# indie anthem-folk      1
# la pop                 1
# ccm                    1
# bebop                  1
# Name: Top Genre, Length: 149, dtype: int64

# %%
df.columns
# Out:
# Index(['Index', 'Title', 'Artist', 'Top Genre', 'Year',
#        'Beats Per Minute (BPM)', 'Energy', 'Danceability', 'Loudness (dB)',
#        'Liveness', 'Valence', 'Length (Duration)', 'Acousticness',
#        'Speechiness', 'Popularity'],
#       dtype='object')

# %%
df['Top Genre'].value_counts()
# Out:
# album rock           413
# adult standards      123
# dutch pop             88
# alternative rock      86
# dance pop             83
#                     ...
# streektaal             1
# indie anthem-folk      1
# la pop                 1
# ccm                    1
# bebop                  1
# Name: Top Genre, Length: 149, dtype: int64

# %%
album_rock = df[df['Top Genre']=='album rock']

# %%
d60s = album_rock[(album_rock['Year']>=1959) & (album_rock['Year']<1969)]['Danceability']

# %%
d70s = album_rock[(album_rock['Year']>=1969) & (album_rock['Year']<1979)]['Danceability']

# %%
d80s = album_rock[(album_rock['Year']>=1979) & (album_rock['Year']<1989)]['Danceability']

# %%
d90s = album_rock[(album_rock['Year']>=1989) & (album_rock['Year']<1999)]['Danceability']

# %%
d10s = album_rock[(album_rock['Year']>=1999) & (album_rock['Year']<2019)]['Danceability']

# %%
df['Top Genre'].value_counts().index
# Out:
# Index(['album rock', 'adult standards', 'dutch pop', 'alternative rock',
#        'dance pop', 'dutch indie', 'alternative metal', 'dance rock',
#        'classic rock', 'dutch cabaret',
#        ...
#        'rock-and-roll', 'classic soundtrack', 'icelandic indie', 'danish pop',
#        'compositional ambient', 'streektaal', 'indie anthem-folk', 'la pop',
#        'ccm', 'bebop'],
#       dtype='object', length=149)

# %%
type(df['Top Genre'].unique())
# Out:
# numpy.ndarray

# %%
df.columns
# Out:
# Index(['Index', 'Title', 'Artist', 'Top Genre', 'Year',
#        'Beats Per Minute (BPM)', 'Energy', 'Danceability', 'Loudness (dB)',
#        'Liveness', 'Valence', 'Length (Duration)', 'Acousticness',
#        'Speechiness', 'Popularity'],
#       dtype='object')

# %%
df_concat = pd.concat([d60s.reset_index(drop=True), d70s.reset_index(drop=True), d80s.reset_index(drop=True), d90s.reset_index(drop=True), d10s.reset_index(drop=True)], axis=1)
df_concat
# Out:
#      Danceability  Danceability  Danceability  Danceability  Danceability
# 0            38.0            34          47.0          57.0          50.0
# 1            60.0            42          57.0          49.0          38.0
# 2            30.0            74          69.0          28.0          56.0
# 3            39.0            56          63.0          51.0          47.0
# 4            60.0            60          77.0          36.0          68.0
# ..            ...           ...           ...           ...           ...
# 181           NaN            86           NaN           NaN           NaN
# 182           NaN            43           NaN           NaN           NaN
# 183           NaN            40           NaN           NaN           NaN
# 184           NaN            46           NaN           NaN           NaN
# 185           NaN            45           NaN           NaN           NaN
#
# [186 rows x 5 columns]

# %%
import matplotlib as mpl
import plotly.express as px
sw = album_rock['Danceability'].sort_values()
sw_01 = (sw - sw.min()) / (sw.max() - sw.min())
sw_colors = {n: mpl.colors.rgb2hex(c) for n, c in zip(sw, mpl.cm.viridis(sw_01))}
colors = [k for k in sw_colors.values()]
# px.strip(iris, 'species', 'sepal_length', 'sepal_width',
#          stripmode='overlay', category_orders={'sepal_width': sw.to_list()[::-1]},
#          color_discrete_map=sw_colors)
px.violin(df_concat, orientation='h', labels={'variable':'album rock'}).update_traces(side="positive", width=5, meanline_visible=True,marker_line_width=10)
# Out:
# <div>                            <div id="4af2595c-ec3b-4c7d-ac5e-677818c756de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4af2595c-ec3b-4c7d-ac5e-677818c756de")) {                    Plotly.newPlot(                        "4af2595c-ec3b-4c7d-ac5e-677818c756de",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"value=%{x}<br>album rock=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","line":{"width":10}},"name":"","offsetgroup":"","orientation":"h","scalegroup":"True","showlegend":false,"x":[38.0,60.0,30.0,39.0,60.0,72.0,48.0,41.0,33.0,53.0,72.0,46.0,60.0,73.0,51.0,60.0,20.0,35.0,55.0,35.0,41.0,52.0,70.0,50.0,53.0,52.0,51.0,68.0,42.0,50.0,39.0,44.0,55.0,63.0,21.0,44.0,44.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,34.0,42.0,74.0,56.0,60.0,59.0,50.0,47.0,22.0,63.0,39.0,47.0,71.0,61.0,54.0,75.0,48.0,35.0,46.0,59.0,37.0,34.0,55.0,55.0,28.0,49.0,44.0,43.0,35.0,39.0,38.0,63.0,68.0,32.0,55.0,56.0,41.0,69.0,56.0,32.0,44.0,39.0,41.0,46.0,63.0,54.0,49.0,57.0,65.0,45.0,26.0,45.0,44.0,56.0,65.0,29.0,54.0,22.0,67.0,56.0,44.0,57.0,68.0,50.0,43.0,23.0,31.0,36.0,28.0,47.0,28.0,55.0,36.0,27.0,48.0,63.0,51.0,60.0,57.0,58.0,41.0,58.0,37.0,60.0,66.0,30.0,64.0,40.0,48.0,51.0,48.0,23.0,27.0,48.0,66.0,41.0,40.0,72.0,67.0,49.0,47.0,39.0,43.0,44.0,79.0,70.0,84.0,58.0,55.0,51.0,38.0,33.0,65.0,52.0,44.0,48.0,51.0,68.0,45.0,55.0,56.0,46.0,62.0,43.0,49.0,33.0,59.0,39.0,41.0,29.0,55.0,29.0,48.0,20.0,68.0,57.0,39.0,49.0,67.0,53.0,67.0,46.0,59.0,70.0,55.0,52.0,81.0,42.0,52.0,59.0,62.0,73.0,62.0,49.0,50.0,84.0,47.0,53.0,54.0,54.0,80.0,76.0,36.0,78.0,55.0,80.0,30.0,63.0,41.0,64.0,51.0,32.0,31.0,32.0,27.0,54.0,72.0,47.0,68.0,27.0,48.0,86.0,43.0,40.0,46.0,45.0,47.0,57.0,69.0,63.0,77.0,58.0,59.0,41.0,53.0,42.0,51.0,64.0,71.0,49.0,55.0,32.0,31.0,60.0,53.0,44.0,38.0,49.0,71.0,31.0,37.0,53.0,80.0,50.0,50.0,56.0,63.0,61.0,40.0,53.0,67.0,38.0,38.0,55.0,25.0,66.0,82.0,38.0,56.0,69.0,60.0,58.0,31.0,82.0,56.0,65.0,65.0,74.0,43.0,70.0,60.0,70.0,51.0,48.0,52.0,40.0,38.0,56.0,62.0,43.0,22.0,67.0,46.0,82.0,60.0,70.0,60.0,69.0,29.0,44.0,54.0,54.0,63.0,56.0,65.0,64.0,58.0,52.0,53.0,62.0,66.0,73.0,42.0,29.0,75.0,71.0,26.0,82.0,74.0,56.0,31.0,61.0,63.0,58.0,52.0,72.0,64.0,68.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,57.0,49.0,28.0,51.0,36.0,62.0,71.0,55.0,50.0,19.0,45.0,46.0,15.0,63.0,59.0,53.0,53.0,35.0,32.0,65.0,48.0,91.0,66.0,74.0,61.0,31.0,56.0,56.0,65.0,66.0,33.0,65.0,41.0,42.0,33.0,57.0,52.0,76.0,75.0,55.0,59.0,76.0,38.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,nu ...

# %%
colors
# Out:
# UsageError: %colors: you must specify a color scheme. See '%colors?'

# %%
df_concat.columns = ['d1','d2','d3','d4','d5']

# %%
df_concat

# %%
import pandas as pd

df = pd.read_csv('Spotify-2000.csv')

# %%
df2 = df.set_index('Title')

# %%
diff = df2['Valence'].values - df2['Valence'].values[:,None]

# %%
import numpy as np

diff_norm = 1-((diff-diff.min())/(diff.max()-diff.min()))
diff_norm[diff_norm<0.5] = 0
np.fill_diagonal(diff_norm, 0)
diff_norm = diff_norm*100

# %%
diff_norm
# Out:
# array([[ 0.        ,  0.        , 58.33333333, ...,  0.        ,
#         54.16666667,  0.        ],
#        [56.77083333,  0.        , 65.10416667, ...,  0.        ,
#         60.9375    ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [65.10416667, 58.33333333, 73.4375    , ...,  0.        ,
#         69.27083333, 57.29166667],
#        [ 0.        ,  0.        , 54.16666667, ...,  0.        ,
#          0.        ,  0.        ],
#        [57.8125    , 51.04166667, 66.14583333, ...,  0.        ,
#         61.97916667,  0.        ]])

# %%
pd.concat((df['Title'], pd.DataFrame(diff, columns=df['Title'])), axis=1)
# Out:
#                        Title  Sunrise  Black Night  Clint Eastwood  \
# 0                    Sunrise        0           13             -16
# 1                Black Night      -13            0             -29
# 2             Clint Eastwood       16           29               0
# 3              The Pretender       31           44              15
# 4     Waitin' On A Sunny Day      -19           -6             -35
# ...                      ...      ...          ...             ...
# 1989        Heartbreak Hotel       -4            9             -20
# 1990               Hound Dog      -27          -14             -43
# 1991         Johnny B. Goode      -29          -16             -45
# 1992               Take Five        8           21              -8
# 1993          Blueberry Hill      -15           -2             -31
#
#       The Pretender  Waitin' On A Sunny Day  \
# 0               -31                      19
# 1               -44                       6
# 2               -15                      35
# 3                 0                      50
# 4               -50                       0
# ...             ...                     ...
# 1989            -35                      15
# 1990            -58                      -8
# 1991            -60                     -10
# 1992            -23                      27
# 1993            -46                       4
#
#       The Road Ahead (Miles Of The Unknown)  She Will Be Loved  \
# 0                                       -54                -14
# 1                                       -67                -27
# 2                                       -38                  2
# 3                                       -23                 17
# 4                                       -73                -33
# ...                                     ...                ...
# 1989                                    -58                -18
# 1990                                    -81                -41
# 1991                                    -83                -43
# 1992                                    -46                 -6
# 1993                                    -69                -29
#
#       Knights of Cydonia  Mr. Brightside  ...  \
# 0                    -47             -45  ...
# 1                    -60             -58  ...
# 2                    -31             -29  ...
# 3                    -16             -14  ...
# 4                    -66             -64  ...
# ...                  ...             ...  ...
# 1989                 -51             -49  ...
# 1990                 -74             -72  ...
# 1991                 -76             -74  ...
# 1992                 -39             -37  ...
# 1993                 -62             -60  ...
#
#       Suite: Judy Blue Eyes - Remastered  Blue Suede Shoes  Jailhouse Rock  \
# 0                                    -38                28              24
# 1                                    -51                15              11
# 2                                    -22                44              40
# 3                                     -7                59              55
# 4                                    -57                 9               5
# ...                                  ...               ...             ...
# 1989                                 -42                24              20
# 1990                                 -65                 1              -3
# 1991                                 -67                -1              -5
# 1992                                 -30                36              32
# 1993                                 -53                13               9
#
#       My Baby Just Cares for Me - 2013 Remastered Version  Summertime  \
# 0                                                   -25           -58
# 1                                                   -38           -71
# 2                                                    -9           -42
# 3                                                     6           -27
# 4                                                   -44           -77
# ...                                                 ...           ...
# 1989                                                -29           -62
# 1990                                                -52           -85
# 1991                                                -54           -87
# 1992                                                -17           -50
# 1993                                                -40           -73
#
#       Heartbreak Hotel  Hound Dog  Johnny B. Goode  Take Five  Blueberry Hill
# 0                    4         27               29         -8              15
# 1                   -9         14               16        -21               2
# 2                   20         43               45          8              31
# 3                   35         58               60         23              46
# 4                  -15          8               10        -27              -4
# ...                ...        ...              ...        ...             ...
# 1989                 0         23               25        -12              11
# 1990               -23          0                2        -35             -12
# 1991               -25         -2                0        -37             -14
# 1992                12         35               37          0              23
# 1993               -11         12               14        -23               0
#
# [1994 rows x 1995 columns]
